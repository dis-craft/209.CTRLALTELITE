# %% [markdown]
# <a href="https://colab.research.google.com/github/dis-craft/209.CTRLALTELITE/blob/main/Final_Score_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
mubashirsidiki_student_academic_performance_500_students_path = kagglehub.dataset_download('mubashirsidiki/student-academic-performance-500-students')

print('Data source import complete.')

# %% [markdown]
# # Student Score performance prediction Using Logistic Regression model:
#
#
#
#
#     About this file
#     Simulated dataset of 500 high school students with demographic info, study habits, and academic performance. Useful for classification (predict pass/fail), regression (predict final score), and exploring how factors like study hours and attendance relate to outcomes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import  accuracy_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # **Data exploration**

# %%
df=pd.read_csv('/kaggle/input/datasets/mubashirsidiki/student-academic-performance-500-students/student_performance.csv')
df.head(8)

# %%
print('The DataSize: ',df.shape)

# %% [markdown]
# ## **Check Null values and data types**
#
#
#
# *   **Missing data can cause errors**
# *   **It is required to handle them with approriate functions**
# *   **NaN-Not a Number**

# %%
# Check Null values

# %%
#Handling Missing Values

# %%
#Checking the type of data

# %% [markdown]
# # **Preprocessing**
# * **convert String to numbers**

# %%
#Find data with categorical values and encode it
df['passed']=
df['gender']=
#Check for the columns that doesn't effect the accuracy of the model
col=['parent_education', 'internet_access', 'extracurricular']
dfe =
#print("The number of Columns After one‑hot encoding:", dfe.shape[1])
#dfe.head()

# %% [markdown]
# # Split The Data into Training and Testing
#
#   *  **Select The Size of Training**
#    * **Select The Size of Testing**

# %%
#Split Features And Target Variables (X,y)
X=
Y=
#Split into training and testing set
X_train,X_test,y_train,y_test=

# %% [markdown]
# ## Feature Scaling
#
#
# *   **It is done on the features in the dataset(X)**
# *   **To scale the feature values at the same level**

# %% [markdown]
# # LogisticRegression
# * **Predict the answers**
# * **Check The Results**
# * **Compare Between The Acutal Score and The Predicted Score**

# %%
#Model Training

# %% [markdown]
# ## **Predicting For A New Value**

# %%
##print(lr.predict(sc.transform([[30,87000]])))

# %% [markdown]
# ## **Predicting the Test set results**

# %%
y_pred=
##print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# ## **Accuracy Score**

# %%
#finding the accuracy score
accuracy_score()
